# %%
final_model = finalize_model(tuned_knn)

# %%
predict_model(
    modelo_carregado, 
    data = novo_cliente
)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges TotalCharges  prediction_label  \
# 0  Electronic check          29.85        29.85                No
#
#   prediction_score
# 0            0.625
#
# [1 rows x 22 columns]

# %%
modelo_carregado = load_model("models/churn_model_v1")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
save_model(tuned_knn, "models/churn_model_v1")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['SeniorCitizen', 'tenure',
#                                               'MonthlyCharges'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False...
#                                      transformer=TargetEncoder(cols=['customerID',
#                                                                      'TotalCharges'],
#                                                                drop_invariant=False,
#                                                                handle_missing='return_nan',
#                                                                handle_unknown='value',
#                                                                hierarchy=None,
#                                                                min_samples_leaf=20,
#                                                                return_df=True,
#                                                                smoothing=10,
#                                                                verbose=0))),
#                  ('trained_model',
#                   KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                        metric='manhattan', metric_params=None,
#                                        n_jobs=-1, n_neighbors=16, p=2,
#                                        weights='uniform'))],
#           verbose=False),
#  'models/churn_model_v1.pkl')

# %%
import os

os.makedirs("models", exist_ok = True)

# %%
predict_model(
    tuned_knn,
    data = novo_cliente
)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges TotalCharges  prediction_label  \
# 0  Electronic check          29.85        29.85                No
#
#   prediction_score
# 0            0.625
#
# [1 rows x 22 columns]

# %%
novo_cliente = df.drop(columns=["Churn"]).iloc[[0]]

# %%
predictions.head(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2937  5312-IRCFR  Female              0     Yes        Yes      64
# 3276  4210-QFJMF  Female              0      No         No       4
# 4374  2718-YSKCS    Male              0     Yes        Yes      71
# 4375  9896-UYMIE    Male              0      No         No      66
# 237   9903-LYSAB    Male              0     Yes         No      18
# 213   4709-LKHYG  Female              0     Yes        Yes      29
# 91    2424-WVHPL    Male              1      No         No       1
# 6523  2834-JKOOW  Female              0      No         No      15
# 5795  7048-GXDAY    Male              0      No         No      39
# 5892  2709-UQGNP    Male              0      No         No      10
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 2937          Yes               Yes     Fiber optic                   No  ...
# 3276          Yes                No     Fiber optic                   No  ...
# 4374          Yes                No              No  No internet service  ...
# 4375          Yes               Yes     Fiber optic                  Yes  ...
# 237           Yes               Yes     Fiber optic                   No  ...
# 213           Yes                No              No  No internet service  ...
# 91            Yes                No     Fiber optic                   No  ...
# 6523           No  No phone service             DSL                  Yes  ...
# 5795          Yes               Yes     Fiber optic                  Yes  ...
# 5892          Yes                No             DSL                  Yes  ...
#
#               StreamingTV      StreamingMovies        Contract  \
# 2937                   No                  Yes        One year
# 3276                   No                  Yes  Month-to-month
# 4374  No internet service  No internet service        Two year
# 4375                  Yes                  Yes        One year
# 237                    No                   No  Month-to-month
# 213   No internet service  No internet service        One year
# 91                     No                   No  Month-to-month
# 6523                   No                   No        One year
# 5795                  Yes                  Yes  Month-to-month
# 5892                   No                   No  Month-to-month
#
#      PaperlessBilling              PaymentMethod MonthlyCharges TotalCharges  \
# 2937              Yes           Electronic check      92.849998      5980.75
# 3276              Yes           Electronic check      79.150002       317.25
# 4374              Yes  Bank transfer (automatic)      19.600000      1387.45
# 4375              Yes  Bank transfer (automatic)     114.300003       7383.7
# 237               Yes           Electronic check      73.150002      1305.95
# 213                No           Electronic check      20.000000       540.05
# 91                 No           Electronic check      74.699997         74.7
# 6523               No               Mailed check      45.900002       693.45
# 5795              Yes           Electronic check     106.400002      4040.65
# 5892              Yes               Mailed check      51.650002        524.5
#
#      Churn  prediction_label prediction_score
# 2937    No                No           0.9375
# 3276   Yes               Yes           0.9375
# 4374    No                No           1.0000
# 4375    No                No           0.8750
# 237     No                No           0.5625
# 213     No                No           1.0000
# 91      No               Yes           0.6875
# 6523    No                No           1.0000
# 5795    No               Yes           0.5625
# 5892    No                No           0.8125
#
# [10 rows x 23 columns]

# %%
predictions = predict_model(tuned_knn)
# Out:
# <style type="text/css">
# </style>
# <table id="T_947ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_947ab_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_947ab_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_947ab_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_947ab_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_947ab_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_947ab_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_947ab_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_947ab_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_947ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_947ab_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_947ab_row0_col1" class="data row0 col1" >0.7908</td>
#       <td id="T_947ab_row0_col2" class="data row0 col2" >0.8279</td>
#       <td id="T_947ab_row0_col3" class="data row0 col3" >0.7908</td>
#       <td id="T_947ab_row0_col4" class="data row0 col4" >0.7772</td>
#       <td id="T_947ab_row0_col5" class="data row0 col5" >0.7778</td>
#       <td id="T_947ab_row0_col6" class="data row0 col6" >0.4070</td>
#       <td id="T_947ab_row0_col7" class="data row0 col7" >0.4177</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(knn)
print(tuned_knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='manhattan',
#                      metric_params=None, n_jobs=-1, n_neighbors=16, p=2,
#                      weights='uniform')

# %%
tuned_knn = tune_model(knn)
# Out:
# <style type="text/css">
# #T_6d4be_row10_col0, #T_6d4be_row10_col1, #T_6d4be_row10_col2, #T_6d4be_row10_col3, #T_6d4be_row10_col4, #T_6d4be_row10_col5, #T_6d4be_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6d4be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d4be_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6d4be_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6d4be_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6d4be_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6d4be_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6d4be_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6d4be_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d4be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d4be_row0_col0" class="data row0 col0" >0.8073</td>
#       <td id="T_6d4be_row0_col1" class="data row0 col1" >0.8446</td>
#       <td id="T_6d4be_row0_col2" class="data row0 col2" >0.8073</td>
#       <td id="T_6d4be_row0_col3" class="data row0 col3" >0.7987</td>
#       <td id="T_6d4be_row0_col4" class="data row0 col4" >0.8009</td>
#       <td id="T_6d4be_row0_col5" class="data row0 col5" >0.4739</td>
#       <td id="T_6d4be_row0_col6" class="data row0 col6" >0.4778</td>
#     </tr>
#     <tr>
#       <th id="T_6d4be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6d4be_row1_col0" class="data row1 col0" >0.7992</td>
#       <td id="T_6d4be_row1_col1" class="data row1 col1" >0.8116</td>
#       <td id="T_6d4be_row1_col2" class="data row1 col2" >0.7992</td>
#       <td id="T_6d4be_row1_col3" class="data row1 col3" >0.7894</td>
#       <td id="T_6d4be_row1_col4" class="data row1 col4" >0.7918</td>
#       <td id="T_6d4be_row1_col5" class="data row1 col5" >0.4489</td>
#       <td id="T_6d4be_row1_col6" class="data row1 col6" >0.4533</td>
#     </tr>
#     <tr>
#       <th id="T_6d4be_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6d4be_row2_col0" class="data row2 col0" >0.7830</td>
#       <td id="T_6d4be_row2_col1" class="data row2 col1" >0.8164</td>
#       <td id="T_6d4be_row2_col2" class="data row2 col2" >0.7830</td>
#       <td id="T_6d4be_row2_col3" class="data row2 col3" >0.7669</td>
#       <td id="T_6d4be_row2_col4" class="data row2 col4" >0.7659</td>
#       <td id="T_6d4be_row2_col5" class="data row2 col5" >0.3719</td>
#       <td id="T_6d4be_row2_col6" class="data row2 col6" >0.3869</td>
#     </tr>
#     <tr>
#       <th id="T_6d4be_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6d4be_row3_col0" class="data row3 col0" >0.8073</td>
#       <td id="T_6d4be_row3_col1" class="data row3 col1" >0.8249</td>
#       <td id="T_6d4be_row3_col2" class="data row3 col2" >0.8073</td>
#       <td id="T_6d4be_row3_col3" class="data row3 col3" >0.7964</td>
#       <td id="T_6d4be_row3_col4" class="data row3 col4" >0.7954</td>
#       <td id="T_6d4be_row3_col5" class="data row3 col5" >0.4544</td>
#       <td id="T_6d4be_row3_col6" class="data row3 col6" >0.4662</td>
#     </tr>
#     <tr>
#       <th id="T_6d4be_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6d4be_row4_col0" class="data row4 col0" >0.7546</td>
#       <td id="T_6d4be_row4_col1" class="data row4 col1" >0.7993</td>
#       <td id="T_6d4be_row4_col2" class="data row4 col2" >0.7546</td>
#       <td id="T_6d4be_row4_col3" class="data row4 col3" >0.7421</td>
#       <td id="T_6d4be_row4_col4" class="data row4 col4" >0.7465</td>
#       <td id="T_6d4be_row4_col5" class="data row4 col5" >0.3337</td>
#       <td id="T_6d4be_row4_col6" class="data row4 col6" >0.3364</td>
#     </tr>
#     <tr>
#       <th id="T_6d4be_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6d4be_row5_col0" class="data row5 col0" >0.7911</td>
#       <td id="T_6d4be_row5_col1" class="data row5 col1" >0.8231</td>
#       <td id="T_6d4be_row5_col2" class="data row5 col2" >0.7911</td>
#       <td id="T_6d4be_row5_col3" class="data row5 col3" >0.7797</td>
#       <td id="T_6d4be_row5_col4" class="data row5 col4" >0.7821</td>
#       <td id="T_6d4be_row5_col5" class="data row5 col5" >0.4239</td>
#       <td id="T_6d4be_row5_col6" class="data row5 col6" >0.4296</td>
#     </tr>
#     <tr>
#       <th id="T_6d4be_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6d4be_row6_col0" class="data row6 col0" >0.7951</td>
#       <td id="T_6d4be_row6_col1" class="data row6 col1" >0.8515</td>
#       <td id="T_6d4be_row6_col2" class="data row6 col2" >0.7951</td>
#       <td id="T_6d4be_row6_col3" class="data row6 col3" >0.7818</td>
#       <td id="T_6d4be_row6_col4" class="data row6 col4" >0.7771</td>
#       <td id="T_6d4be_row6_col5" class="data row6 col5" >0.4005</td>
#       <td id="T_6d4be_row6_col6" class="data row6 col6" >0.4203</td>
#     </tr>
#     <tr>
#       <th id="T_6d4be_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6d4be_row7_col0" class="data row7 col0" >0.7951</td>
#       <td id="T_6d4be_row7_col1" class="data row7 col1" >0.8302</td>
#       <td id="T_6d4be_row7_col2" class="data row7 col2" >0.7951</td>
#       <td id="T_6d4be_row7_col3" class="data row7 col3" >0.7821</td>
#       <td id="T_6d4be_row7_col4" class="data row7 col4" >0.7816</td>
#       <td id="T_6d4be_row7_col5" class="data row7 col5" >0.4168</td>
#       <td id="T_6d4be_row7_col6" class="data row7 col6" >0.4290</td>
#     </tr>
#     <tr>
#       <th id="T_6d4be_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6d4be_row8_col0" class="data row8 col0" >0.8073</td>
#       <td id="T_6d4be_row8_col1" class="data row8 col1" >0.8304</td>
#       <td id="T_6d4be_row8_col2" class="data row8 col2" >0.8073</td>
#       <td id="T_6d4be_row8_col3" class="data row8 col3" >0.7973</td>
#       <td id="T_6d4be_row8_col4" class="data row8 col4" >0.7983</td>
#       <td id="T_6d4be_row8_col5" class="data row8 col5" >0.4659</td>
#       <td id="T_6d4be_row8_col6" class="data row8 col6" >0.4731</td>
#     </tr>
#     <tr>
#       <th id="T_6d4be_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6d4be_row9_col0" class="data row9 col0" >0.7890</td>
#       <td id="T_6d4be_row9_col1" class="data row9 col1" >0.8203</td>
#       <td id="T_6d4be_row9_col2" class="data row9 col2" >0.7890</td>
#       <td id="T_6d4be_row9_col3" class="data row9 col3" >0.7744</td>
#       <td id="T_6d4be_row9_col4" class="data row9 col4" >0.7679</td>
#       <td id="T_6d4be_row9_col5" class="data row9 col5" >0.3740</td>
#       <td id="T_6d4be_row9_col6" class="data row9 col6" >0.3973</td>
#     </tr>
#     <tr>
#       <th id="T_6d4be_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6d4be_row10_col0" class="data row10 col0" >0.7929</td>
#       <td id="T_6d4be_row10_col1" class="data row10 col1" >0.8252</td>
#       <td id="T_6d4be_row10_col2" class="data row10 col2" >0.7929</td>
#       <td id="T_6d4be_row10_col3" class="data row10 col3" >0.7809</td>
#       <td id="T_6d4be_row10_col4" class="data row10 col4" >0.7808</td>
#       <td id="T_6d4be_row10_col5" class="data row10 col5" >0.4164</td>
#       <td id="T_6d4be_row10_col6" class="data row10 col6" >0.4270</td>
#     </tr>
#     <tr>
#       <th id="T_6d4be_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6d4be_row11_col0" class="data row11 col0" >0.0150</td>
#       <td id="T_6d4be_row11_col1" class="data row11 col1" >0.0144</td>
#       <td id="T_6d4be_row11_col2" class="data row11 col2" >0.0150</td>
#       <td id="T_6d4be_row11_col3" class="data row11 col3" >0.0163</td>
#       <td id="T_6d4be_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
evaluate_model(knn)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
knn = create_model(best_model)
# Out:
# <style type="text/css">
# #T_6ee58_row10_col0, #T_6ee58_row10_col1, #T_6ee58_row10_col2, #T_6ee58_row10_col3, #T_6ee58_row10_col4, #T_6ee58_row10_col5, #T_6ee58_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6ee58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ee58_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6ee58_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6ee58_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6ee58_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6ee58_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6ee58_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6ee58_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ee58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ee58_row0_col0" class="data row0 col0" >0.7911</td>
#       <td id="T_6ee58_row0_col1" class="data row0 col1" >0.8131</td>
#       <td id="T_6ee58_row0_col2" class="data row0 col2" >0.7911</td>
#       <td id="T_6ee58_row0_col3" class="data row0 col3" >0.7916</td>
#       <td id="T_6ee58_row0_col4" class="data row0 col4" >0.7913</td>
#       <td id="T_6ee58_row0_col5" class="data row0 col5" >0.4633</td>
#       <td id="T_6ee58_row0_col6" class="data row0 col6" >0.4633</td>
#     </tr>
#     <tr>
#       <th id="T_6ee58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ee58_row1_col0" class="data row1 col0" >0.7627</td>
#       <td id="T_6ee58_row1_col1" class="data row1 col1" >0.7806</td>
#       <td id="T_6ee58_row1_col2" class="data row1 col2" >0.7627</td>
#       <td id="T_6ee58_row1_col3" class="data row1 col3" >0.7633</td>
#       <td id="T_6ee58_row1_col4" class="data row1 col4" >0.7630</td>
#       <td id="T_6ee58_row1_col5" class="data row1 col5" >0.3903</td>
#       <td id="T_6ee58_row1_col6" class="data row1 col6" >0.3904</td>
#     </tr>
#     <tr>
#       <th id="T_6ee58_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ee58_row2_col0" class="data row2 col0" >0.7748</td>
#       <td id="T_6ee58_row2_col1" class="data row2 col1" >0.7644</td>
#       <td id="T_6ee58_row2_col2" class="data row2 col2" >0.7748</td>
#       <td id="T_6ee58_row2_col3" class="data row2 col3" >0.7673</td>
#       <td id="T_6ee58_row2_col4" class="data row2 col4" >0.7703</td>
#       <td id="T_6ee58_row2_col5" class="data row2 col5" >0.4011</td>
#       <td id="T_6ee58_row2_col6" class="data row2 col6" >0.4025</td>
#     </tr>
#     <tr>
#       <th id="T_6ee58_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ee58_row3_col0" class="data row3 col0" >0.7789</td>
#       <td id="T_6ee58_row3_col1" class="data row3 col1" >0.7894</td>
#       <td id="T_6ee58_row3_col2" class="data row3 col2" >0.7789</td>
#       <td id="T_6ee58_row3_col3" class="data row3 col3" >0.7683</td>
#       <td id="T_6ee58_row3_col4" class="data row3 col4" >0.7717</td>
#       <td id="T_6ee58_row3_col5" class="data row3 col5" >0.3998</td>
#       <td id="T_6ee58_row3_col6" class="data row3 col6" >0.4030</td>
#     </tr>
#     <tr>
#       <th id="T_6ee58_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6ee58_row4_col0" class="data row4 col0" >0.7505</td>
#       <td id="T_6ee58_row4_col1" class="data row4 col1" >0.7297</td>
#       <td id="T_6ee58_row4_col2" class="data row4 col2" >0.7505</td>
#       <td id="T_6ee58_row4_col3" class="data row4 col3" >0.7464</td>
#       <td id="T_6ee58_row4_col4" class="data row4 col4" >0.7483</td>
#       <td id="T_6ee58_row4_col5" class="data row4 col5" >0.3496</td>
#       <td id="T_6ee58_row4_col6" class="data row4 col6" >0.3498</td>
#     </tr>
#     <tr>
#       <th id="T_6ee58_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6ee58_row5_col0" class="data row5 col0" >0.7546</td>
#       <td id="T_6ee58_row5_col1" class="data row5 col1" >0.7692</td>
#       <td id="T_6ee58_row5_col2" class="data row5 col2" >0.7546</td>
#       <td id="T_6ee58_row5_col3" class="data row5 col3" >0.7462</td>
#       <td id="T_6ee58_row5_col4" class="data row5 col4" >0.7496</td>
#       <td id="T_6ee58_row5_col5" class="data row5 col5" >0.3472</td>
#       <td id="T_6ee58_row5_col6" class="data row5 col6" >0.3483</td>
#     </tr>
#     <tr>
#       <th id="T_6ee58_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6ee58_row6_col0" class="data row6 col0" >0.7708</td>
#       <td id="T_6ee58_row6_col1" class="data row6 col1" >0.7998</td>
#       <td id="T_6ee58_row6_col2" class="data row6 col2" >0.7708</td>
#       <td id="T_6ee58_row6_col3" class="data row6 col3" >0.7558</td>
#       <td id="T_6ee58_row6_col4" class="data row6 col4" >0.7593</td>
#       <td id="T_6ee58_row6_col5" class="data row6 col5" >0.3613</td>
#       <td id="T_6ee58_row6_col6" class="data row6 col6" >0.3677</td>
#     </tr>
#     <tr>
#       <th id="T_6ee58_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6ee58_row7_col0" class="data row7 col0" >0.7850</td>
#       <td id="T_6ee58_row7_col1" class="data row7 col1" >0.7956</td>
#       <td id="T_6ee58_row7_col2" class="data row7 col2" >0.7850</td>
#       <td id="T_6ee58_row7_col3" class="data row7 col3" >0.7739</td>
#       <td id="T_6ee58_row7_col4" class="data row7 col4" >0.7769</td>
#       <td id="T_6ee58_row7_col5" class="data row7 col5" >0.4118</td>
#       <td id="T_6ee58_row7_col6" class="data row7 col6" >0.4161</td>
#     </tr>
#     <tr>
#       <th id="T_6ee58_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6ee58_row8_col0" class="data row8 col0" >0.7870</td>
#       <td id="T_6ee58_row8_col1" class="data row8 col1" >0.7853</td>
#       <td id="T_6ee58_row8_col2" class="data row8 col2" >0.7870</td>
#       <td id="T_6ee58_row8_col3" class="data row8 col3" >0.7809</td>
#       <td id="T_6ee58_row8_col4" class="data row8 col4" >0.7833</td>
#       <td id="T_6ee58_row8_col5" class="data row8 col5" >0.4364</td>
#       <td id="T_6ee58_row8_col6" class="data row8 col6" >0.4374</td>
#     </tr>
#     <tr>
#       <th id="T_6ee58_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6ee58_row9_col0" class="data row9 col0" >0.7647</td>
#       <td id="T_6ee58_row9_col1" class="data row9 col1" >0.7605</td>
#       <td id="T_6ee58_row9_col2" class="data row9 col2" >0.7647</td>
#       <td id="T_6ee58_row9_col3" class="data row9 col3" >0.7518</td>
#       <td id="T_6ee58_row9_col4" class="data row9 col4" >0.7558</td>
#       <td id="T_6ee58_row9_col5" class="data row9 col5" >0.3563</td>
#       <td id="T_6ee58_row9_col6" class="data row9 col6" >0.3600</td>
#     </tr>
#     <tr>
#       <th id="T_6ee58_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6ee58_row10_col0" class="data row10 col0" >0.7720</td>
#       <td id="T_6ee58_row10_col1" class="data row10 col1" >0.7787</td>
#       <td id="T_6ee58_row10_col2" class="data row10 col2" >0.7720</td>
#       <td id="T_6ee58_row10_col3" class="data row10 col3" >0.7645</td>
#       <td id="T_6ee58_row10_col4" class="data row10 col4" >0.7669</td>
#       <td id="T_6ee58_row10_col5" class="data row10 col5" >0.3917</td>
#       <td id="T_6ee58_row10_col6" class="data row10 col6" >0.3939</td>
#     </tr>
#     <tr>
#       <th id="T_6ee58_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6ee58_row11_col0" class="data row11 col0" >0.0131</td>
#       <td id="T_6ee58_row11_col1" class="data row11 col1" >0.0226</td>
#       <td id="T_6ee58_row11_col2" class="data row11 col2" >0.0131</td>
#       <td id="T_6ee58_row11_col3" class="data row11 col3" >0.0142</td>
#       <td id="T_6ee58_row11_col4

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_95afa th {
#   text-align: left;
# }
# #T_95afa_row0_col0, #T_95afa_row0_col2, #T_95afa_row1_col0, #T_95afa_row1_col1, #T_95afa_row1_col3, #T_95afa_row1_col4, #T_95afa_row1_col5, #T_95afa_row1_col6, #T_95afa_row1_col7, #T_95afa_row2_col0, #T_95afa_row2_col1, #T_95afa_row2_col2, #T_95afa_row2_col3, #T_95afa_row2_col4, #T_95afa_row2_col5, #T_95afa_row2_col6, #T_95afa_row2_col7, #T_95afa_row3_col0, #T_95afa_row3_col1, #T_95afa_row3_col2, #T_95afa_row3_col3, #T_95afa_row3_col4, #T_95afa_row3_col5, #T_95afa_row3_col6, #T_95afa_row3_col7, #T_95afa_row4_col0, #T_95afa_row4_col1, #T_95afa_row4_col2, #T_95afa_row4_col3, #T_95afa_row4_col4, #T_95afa_row4_col5, #T_95afa_row4_col6, #T_95afa_row4_col7, #T_95afa_row5_col0, #T_95afa_row5_col1, #T_95afa_row5_col2, #T_95afa_row5_col3, #T_95afa_row5_col4, #T_95afa_row5_col5, #T_95afa_row5_col6, #T_95afa_row5_col7, #T_95afa_row6_col0, #T_95afa_row6_col1, #T_95afa_row6_col2, #T_95afa_row6_col3, #T_95afa_row6_col4, #T_95afa_row6_col5, #T_95afa_row6_col6, #T_95afa_row6_col7, #T_95afa_row7_col0, #T_95afa_row7_col1, #T_95afa_row7_col2, #T_95afa_row7_col3, #T_95afa_row7_col4, #T_95afa_row7_col5, #T_95afa_row7_col6, #T_95afa_row7_col7, #T_95afa_row8_col0, #T_95afa_row8_col1, #T_95afa_row8_col2, #T_95afa_row8_col3, #T_95afa_row8_col4, #T_95afa_row8_col5, #T_95afa_row8_col6, #T_95afa_row8_col7, #T_95afa_row9_col0, #T_95afa_row9_col1, #T_95afa_row9_col2, #T_95afa_row9_col3, #T_95afa_row9_col4, #T_95afa_row9_col5, #T_95afa_row9_col6, #T_95afa_row9_col7, #T_95afa_row10_col0, #T_95afa_row10_col1, #T_95afa_row10_col2, #T_95afa_row10_col3, #T_95afa_row10_col4, #T_95afa_row10_col5, #T_95afa_row10_col6, #T_95afa_row10_col7, #T_95afa_row11_col0, #T_95afa_row11_col1, #T_95afa_row11_col2, #T_95afa_row11_col3, #T_95afa_row11_col4, #T_95afa_row11_col5, #T_95afa_row11_col6, #T_95afa_row11_col7, #T_95afa_row12_col0, #T_95afa_row12_col1, #T_95afa_row12_col2, #T_95afa_row12_col3, #T_95afa_row12_col4, #T_95afa_row12_col5, #T_95afa_row12_col6, #T_95afa_row12_col7 {
#   text-align: left;
# }
# #T_95afa_row0_col1, #T_95afa_row0_col3, #T_95afa_row0_col4, #T_95afa_row0_col5, #T_95afa_row0_col6, #T_95afa_row0_col7, #T_95afa_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_95afa_row0_col8, #T_95afa_row1_col8, #T_95afa_row3_col8, #T_95afa_row5_col8, #T_95afa_row6_col8, #T_95afa_row7_col8, #T_95afa_row8_col8, #T_95afa_row9_col8, #T_95afa_row10_col8, #T_95afa_row11_col8, #T_95afa_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_95afa_row2_col8, #T_95afa_row4_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_95afa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95afa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_95afa_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_95afa_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_95afa_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_95afa_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_95afa_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_95afa_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_95afa_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_95afa_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95afa_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_95afa_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_95afa_row0_col1" class="data row0 col1" >0.7720</td>
#       <td id="T_95afa_row0_col2" class="data row0 col2" >0.7787</td>
#       <td id="T_95afa_row0_col3" class="data row0 col3" >0.7720</td>
#       <td id="T_95afa_row0_col4" class="data row0 col4" >0.7645</td>
#       <td id="T_95afa_row0_col5" class="data row0 col5" >0.7669</td>
#       <td id="T_95afa_row0_col6" class="data row0 col6" >0.3917</td>
#       <td id="T_95afa_row0_col7" class="data row0 col7" >0.3939</td>
#       <td id="T_95afa_row0_col8" class="data row0 col8" >0.2580</td>
#     </tr>
#     <tr>
#       <th id="T_95afa_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_95afa_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_95afa_row1_col1" class="data row1 col1" >0.7448</td>
#       <td id="T_95afa_row1_col2" class="data row1 col2" >0.8353</td>
#       <td id="T_95afa_row1_col3" class="data row1 col3" >0.7448</td>
#       <td id="T_95afa_row1_col4" class="data row1 col4" >0.7438</td>
#       <td id="T_95afa_row1_col5" class="data row1 col5" >0.6541</td>
#       <td id="T_95afa_row1_col6" class="data row1 col6" >0.0727</td>
#       <td id="T_95afa_row1_col7" class="data row1 col7" >0.1565</td>
#       <td id="T_95afa_row1_col8" class="data row1 col8" >0.3130</td>
#     </tr>
#     <tr>
#       <th id="T_95afa_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_95afa_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_95afa_row2_col1" class="data row2 col1" >0.7416</td>
#       <td id="T_95afa_row2_col2" class="data row2 col2" >0.7839</td>
#       <td id="T_95afa_row2_col3" class="data row2 col3" >0.7416</td>
#       <td id="T_95afa_row2_col4" class="data row2 col4" >0.7155</td>
#       <td id="T_95afa_row2_col5" class="data row2 col5" >0.6534</td>
#       <td id="T_95afa_row2_col6" class="data row2 col6" >0.0687</td>
#       <td id="T_95afa_row2_col7" class="data row2 col7" >0.1358</td>
#       <td id="T_95afa_row2_col8" class="data row2 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_95afa_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_95afa_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_95afa_row3_col1" class="data row3 col1" >0.7355</td>
#       <td id="T_95afa_row3_col2" class="data row3 col2" >0.5796</td>
#       <td id="T_95afa_row3_col3" class="data row3 col3" >0.7355</td>
#       <td id="T_95afa_row3_col4" class="data row3 col4" >0.6399</td>
#       <td id="T_95afa_row3_col5" class="data row3 col5" >0.6291</td>
#       <td id="T_95afa_row3_col6" class="data row3 col6" >0.0142</td>
#       <td id="T_95afa_row3_col7" class="data row3 col7" >0.0355</td>
#       <td id="T_95afa_row3_col8" class="data row3 col8" >0.0600</td>
#     </tr>
#     <tr>
#       <th id="T_95afa_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_95afa_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_95afa_row4_col1" class="data row4 col1" >0.7347</td>
#       <td id="T_95afa_row4_col2" class="data row4 col2" >0.5000</td>
#       <td id="T_95afa_row4_col3" class="data row4 col3" >0.7347</td>
#       <td id="T_95afa_row4_col4" class="data row4 col4" >0.5398</td>
#       <td id="T_95afa_row4_col5" class="data row4 col5" >0.6223</td>
#       <td id="T_95afa_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_95afa_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_95afa_row4_col8" class="data row4 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_95afa_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_95afa_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_95afa_row5_col1" class="data row5 col1" >0.7347</td>
#       <td id="T_95afa_row5_col2" class="data row5 col2" >0.5000</td>
#       <td id="T_95afa_row5_col3" class="data row5 col3" >0.7347</td>
#       <td id="T_95afa_row5_col4" class="data row5 col4" >0.5398</td>
#       <td id="T_95afa_row5_col5" class="data row5 col5" >0.6223</td>
#       <td id="T_95afa_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_95afa_row5_col7" class="data row5 col7" >0.0000</td>
#       <td id="T_95afa_row5_col8" class="data row5 col8" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_95afa_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_95afa_row6_col0" class="data row6 col0" >Random F

# %%
clf = setup(
    data = df,
    target = "Churn",
    session_id = 123
)
# Out:
# <style type="text/css">
# #T_9d358_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9d358">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d358_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9d358_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d358_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d358_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9d358_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d358_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9d358_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d358_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9d358_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9d358_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_9d358_row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9d358_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_9d358_row4_col1" class="data row4 col1" >(7043, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9d358_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_9d358_row5_col1" class="data row5 col1" >(7043, 42)</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9d358_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_9d358_row6_col1" class="data row6 col1" >(4930, 42)</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9d358_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_9d358_row7_col1" class="data row7 col1" >(2113, 42)</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9d358_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_9d358_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9d358_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_9d358_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9d358_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_9d358_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9d358_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_9d358_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9d358_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_9d358_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9d358_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_9d358_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9d358_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_9d358_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9d358_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_9d358_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9d358_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_9d358_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9d358_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_9d358_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9d358_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_9d358_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9d358_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_9d358_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9d358_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_9d358_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9d358_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_9d358_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9d358_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9d358_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_9d358_row22_col1" class="data row22 col1" >2c29</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.classification import *

# %%
df["TotalCharges"].value_counts().head()
# Out:
# TotalCharges
#          11
# 20.2     11
# 19.75     9
# 20.05     8
# 19.9      8
# Name: count, dtype: int64

# %%
df["TotalCharges"].dtype
# Out:
# dtype('O')

# %%
# Ver se tem algum valor nulo na planilha
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (7043, 21)

# %%
import pandas as pd

df = pd.read_csv("../data/Telco-Customer-Churn.csv")

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
import pycaret

print(pycaret.__version__)
# Out:
# 3.3.2

# %%
import sys

print(sys.version)
# Out:
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
